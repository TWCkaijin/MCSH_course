# %% [markdown]
# 請在不使用套件的狀況下完成遞迴排列組合

# %%
def permutation(arr , start , end):
    pass


array = [1,2,3]
permutation(array, 0, 3)
# Out:
# [5, 1, 2, 3, 4]
# [5, 1, 2, 4, 3]
# [5, 1, 3, 4, 2]
# [5, 1, 3, 2, 4]
# [5, 1, 3, 2, 4]
# [5, 1, 3, 4, 2]
# [5, 2, 3, 1, 4]
# [5, 2, 3, 4, 1]
# [5, 2, 1, 4, 3]
# [5, 2, 1, 3, 4]
# [5, 2, 1, 3, 4]
# [5, 2, 1, 4, 3]
# [5, 2, 4, 3, 1]
# [5, 2, 4, 1, 3]
# [5, 2, 3, 1, 4]
# [5, 2, 3, 4, 1]
# [5, 2, 3, 4, 1]
# [5, 2, 3, 1, 4]
# [5, 2, 1, 3, 4]
# [5, 2, 1, 4, 3]
# [5, 2, 3, 4, 1]
# [5, 2, 3, 1, 4]
# [5, 2, 3, 1, 4]
# [5, 2, 3, 4, 1]
# [1, 2, 5, 3, 4]
# [1, 2, 5, 4, 3]
# [1, 2, 3, 4, 5]
# [1, 2, 3, 5, 4]
# [1, 2, 3, 5, 4]
# [1, 2, 3, 4, 5]
# [1, 5, 3, 2, 4]
# [1, 5, 3, 4, 2]
# [1, 5, 2, 4, 3]
# [1, 5, 2, 3, 4]
# [1, 5, 2, 3, 4]
# [1, 5, 2, 4, 3]
# [1, 5, 4, 3, 2]
# [1, 5, 4, 2, 3]
# [1, 5, 3, 2, 4]
# [1, 5, 3, 4, 2]
# [1, 5, 3, 4, 2]
# [1, 5, 3, 2, 4]
# [1, 5, 2, 3, 4]
# [1, 5, 2, 4, 3]
# [1, 5, 3, 4, 2]
# [1, 5, 3, 2, 4]
# [1, 5, 3, 2, 4]
# [1, 5, 3, 4, 2]
# [1, 3, 2, 5, 4]
# [1, 3, 2, 4, 5]
# [1, 3, 5, 4, 2]
# [1, 3, 5, 2, 4]
# [1, 3, 5, 2, 4]
# [1, 3, 5, 4, 2]
# [1, 2, 5, 3, 4]
# ...
